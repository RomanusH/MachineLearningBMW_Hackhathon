# %%
import pandas as pd
import numpy as np

# %%
#pd.reset_option("all")
#pd.reset_option("display.max_columns")
#pd.reset_option("display.max_rows")

# %%
data = pd.read_csv('test.csv', header=0)
#data3 = pd.read_csv('train.csv', header=0)

data.describe()
# Out:
#        s6_sensor0_millimeter_step1  s8_sensor0_millimeter_step1  \
# count                   394.000000                   393.000000
# mean                   5022.168485                    20.531581
# std                     600.021865                     1.821298
# min                    4606.469076                    17.127204
# 25%                    4606.469076                    19.141099
# 50%                    4606.469076                    20.388415
# 75%                    5886.043819                    21.768258
# max                    5886.043819                    28.319264
#
#        s8_sensor1_millimeter_step1  s7_sensor0_newton_step1  \
# count                   393.000000               390.000000
# mean                    386.728621              8864.679710
# std                      33.464963                13.393429
# min                     287.942629              8820.628829
# 25%                     363.995662              8854.226959
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Columns: 375 entries, physical_part_type to s3_sensor3_newtonmeter_step1
# dtypes: float64(370), object(5)
# memory usage: 1.1+ MB

# %%
list(data.columns.values)
# Out:
# ['physical_part_type',
#  'message_timestamp',
#  'weekday',
#  'shift',
#  'physical_part_id',
#  's6_sensor0_millimeter_step1',
#  's8_sensor0_millimeter_step1',
#  's8_sensor1_millimeter_step1',
#  's7_sensor0_newton_step1',
#  's9_sensor0_kilonewton_step1',
#  's7_sensor1_mikrometer_step1',
#  's0_sensor0_kilonewton_step3',
#  's2_sensor0_millimeter_step1',
#  's9_sensor1_sekunden (zeit)_step1',
#  's8_sensor2_millimeter_step1',
#  's0_sensor1_millimeter_step1',
#  's9_sensor2_sekunden (zeit)_step1',
#  's7_sensor2_mikroohm_step1',
#  's8_sensor3_millimeter_step1',
#  's7_sensor3_cse_step1',
#  's8_sensor4_prozent_step1',
#  's7_sensor4_watt/sekunde_step1',
#  's8_sensor5_dm_step1',
#  's6_sensor1_kilonewton_step1',
#  's7_sensor5_mikrometer_step1',
#  's7_sensor6_newton_step1',
#  's0_sensor2_millimeter_step1',
#  's8_sensor6_millimeter_step1',
#  's4_sensor0_sekunden (zeit)_step1',
#  's0_sensor3_kilonewton_step1',
#  's7_sensor7_cse_step1',
#  's0_sensor4_kilonewton_step1',
# ...

# %%
data_amount = pd.DataFrame({
    "Column": data.columns,                     
    "Non-NaN Values": data.notna().sum().values 
})

data_amount
#as we can see from here, only numerical values have NaN entries. Therefore, we can replace them with mean or mode.
# Out:
#                             Column  Non-NaN Values
# 0               physical_part_type             400
# 1                message_timestamp             400
# 2                          weekday             400
# 3                            shift             400
# 4                 physical_part_id             400
# ..                             ...             ...
# 370   s7_sensor50_mikrometer_step1             393
# 371   s2_sensor25_millimeter_step1             387
# 372      s8_sensor121_binaer_step1             393
# 373  s8_sensor122_millimeter_step1             393
# 374   s3_sensor3_newtonmeter_step1             387
#
# [375 rows x 2 columns]

# %%
duplicate_rows = data.duplicated()
print(duplicate_rows.sum())
# Out:
# 0

# %%
#pd.set_option("display.max_columns", None)
#pd.set_option("display.max_rows", None)
#data3
data.describe()
# Out:
#        s6_sensor0_millimeter_step1  s8_sensor0_millimeter_step1  \
# count                   394.000000                   393.000000
# mean                   5022.168485                    20.531581
# std                     600.021865                     1.821298
# min                    4606.469076                    17.127204
# 25%                    4606.469076                    19.141099
# 50%                    4606.469076                    20.388415
# 75%                    5886.043819                    21.768258
# max                    5886.043819                    28.319264
#
#        s8_sensor1_millimeter_step1  s7_sensor0_newton_step1  \
# count                   393.000000               390.000000
# mean                    386.728621              8864.679710
# std                      33.464963                13.393429
# min                     287.942629              8820.628829
# 25%                     363.995662              8854.226959
# ...

# %%
# 1. Replace missing values with 0
data_zero = data.copy()
data_zero.fillna(0, inplace=True)

# 2. Leave the missing values as they are
data_as_is = data.copy()

# %%
# 1. Replace missing values with the mode
data_mode = data.copy()
for col in data_mode.select_dtypes(include=['number']).columns:  # Only numeric columns
    data_mode[col].fillna(data_mode[col].mode()[0], inplace=True)

# 2. Replace missing values with the median
data_median = data.copy()
data_median.fillna(data_median.median(), inplace=True)

# 3. Replace missing values with the mean
data_mean = data.copy()
data_mean.fillna(data_mean.mean(), inplace=True)
# Out:
# /var/folders/z5/gzfc5ljn0213zgjx73wh66bh0000gn/T/ipykernel_14241/4152871275.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_mode[col].fillna(data_mode[col].mode()[0], inplace=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# ...
